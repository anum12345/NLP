# %%
import pandas as pd
df=pd.read_csv("Salman_Khan_VS_Sharuk_Khan - Sheet2.csv")
df.head()
# Out:
#                       Name                                            Comment  \
# 0                Obed Khan                             Shah Rukh Khan sirf ek
# 1              Aasif Patel                                        Salman khan
# 2         V Shejule Status                Only Salman bhai<br>Bhot Hard Bhai✌
# 3     Avinash Tudu rushika             Bollywood ka sabse bada super star srk
# 4  DexterDrubo Animations-  In India Salman Khan has bigger stardom than S...
#
#                    Time  Likes  Reply Count       Supporter  Unnamed: 6  \
# 0  2023-01-30T02:44:56Z      0            0  Shahrukh  khan         NaN
# 1  2023-01-29T13:49:48Z      0            0     Salman Khan         NaN
# 2  2023-01-28T17:53:55Z      0            0     Salman Khan         NaN
# 3  2023-01-28T17:38:39Z      0            0  Shahrukh  khan         NaN
# 4  2023-01-28T11:34:45Z      0            0  Shahrukh  khan         NaN
#
#    Unnamed: 7  Unnamed: 8  Unnamed: 9 Unnamed: 10
# ...

# %%
df=df.iloc[:,1:6:4]
df
# Out:
#                                                Comment       Supporter
# 0                               Shah Rukh Khan sirf ek  Shahrukh  khan
# 1                                          Salman khan     Salman Khan
# 2                  Only Salman bhai<br>Bhot Hard Bhai✌     Salman Khan
# 3               Bollywood ka sabse bada super star srk  Shahrukh  khan
# 4    In India Salman Khan has bigger stardom than S...  Shahrukh  khan
# ..                                                 ...             ...
# 995                                          srk rocks    Sharukh Khan
# 996  Sha Rukh Khan is an international Star he gets...    Sharukh Khan
# 997  SALMAN KHAN iS SUPPAR😍😍😍😍😍🤗😍😍🤗😍🤗🤗😍🤗🤗🤗🤗😍😍🤗😍😍😍😍😍...     Salman Khan
# 998                                           Srk = sk    Sharukh Khan
# 999                                    Shah Rukh Khan👑    Sharukh Khan
#
# [1000 rows x 2 columns]

# %%
X=df.iloc[:,0]
Y=df.iloc[:,1]
